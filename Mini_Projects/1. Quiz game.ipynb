# %%
print("\n You have to ans 3 out 5 question in order to  pass this test")

score=0
write=0
wrong=0

user=input("\nDo you want to play?")

if user=='y'or user=='Y':
    
        print("\nQuestion:-1 ")

        q1=input("\nWho is the CM of Delhi?")
        
        if q1=='kejriwal':
            print("Correct!")
            score+=5
            write+=1

        else:
            print('Wrong')
            wrong+=1
            
        q2=input("\n Who is the King of Bollywood?")
        
        if q2=='shahrukh khan':
            print('Correct')
            score+=5
            write+=1

        else:
            print('Wrong')
            wrong+=1

        
            
        q3=input("\n Who is the Presindent of India?")
        
        if q3=='murmuni':
            print('Correct')
            score+=5
            write+=1
        
        else:
            print('Wrong')
            wrong+=1
            
        q4=input("\n What is the short form of Narvarachana university?")
        
        if q4=='nuv':
            print('Correct')
            score+=5
            write+=1

        else:
            print('Wrong')
            wrong+=1
            
        q5=input("\nWho is the Sachin Tendulker?")
        
        if q5=='cricketer':
            print('Correct')
            score+=5
            write+=1

        else:
            print('Wrong')
            wrong+=1
        


       

        

       
        
        
        # To chcek for 3 out 5
        if wrong>=3:
            print("\nFailed!")
        
        else:
            print("\nCongratulation--Pass")



        print(f"\n Your Score is: {score}")

        print(f"\nWrong answer :{wrong}")


        print(f"Percentage you got: {(write/5)*100}%")  # write/total subjects*100
    
else:
    print("You choose no")
# Out:
#  You have to ans 3 out 5 question in order to  pass this test
#
# Do you want to play?y
#
# Question:-1
#
# Who is the CM of Delhi?kejriwal
# Correct!
#
#  Who is the King of Bollywood?shahrukh khan
# Correct
#
#  Who is the Presindent of India?modi
# Wrong
#
#  What is the short form of Narvarachana university?nuv
# Correct
#
# Who is the Sachin Tendulker?cricket
# Wrong
#
# Congratulation--Pass
#
#  Your Score is: 15
#
# Wrong answer :2
# Percentage you got: 60.0%
